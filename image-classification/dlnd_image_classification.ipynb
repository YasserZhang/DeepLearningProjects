# %% [markdown]
# # Image Classification
# In this project, you'll classify images from the [CIFAR-10 dataset](https://www.cs.toronto.edu/~kriz/cifar.html).  The dataset consists of airplanes, dogs, cats, and other objects. You'll preprocess the images, then train a convolutional neural network on all the samples. The images need to be normalized and the labels need to be one-hot encoded.  You'll get to apply what you learned and build a convolutional, max pooling, dropout, and fully connected layers.  At the end, you'll get to see your neural network's predictions on the sample images.
# ## Get the Data
# Run the following cell to download the [CIFAR-10 dataset for python](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = '/input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## Explore the Data
# The dataset is broken into batches to prevent your machine from running out of memory.  The CIFAR-10 dataset consists of 5 batches, named `data_batch_1`, `data_batch_2`, etc.. Each batch contains the labels and images that are one of the following:
# * airplane
# * automobile
# * bird
# * cat
# * deer
# * dog
# * frog
# * horse
# * ship
# * truck
#
# Understanding a dataset is part of making predictions on the data.  Play around with the code cell below by changing the `batch_id` and `sample_id`. The `batch_id` is the id for a batch (1-5). The `sample_id` is the id for a image and label pair in the batch.
#
# Ask yourself "What are all possible labels?", "What is the range of values for the image data?", "Are the labels in order or random?".  Answers to questions like these will help you preprocess the data and end up with better predictions.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## Implement Preprocess Functions
# ### Normalize
# In the cell below, implement the `normalize` function to take in image data, `x`, and return it as a normalized Numpy array. The values should be in the range of 0 to 1, inclusive.  The return object should be the same shape as `x`.

# %%
import numpy as np
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    return x/255


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot encode
# Just like the previous code cell, you'll be implementing a function for preprocessing.  This time, you'll implement the `one_hot_encode` function. The input, `x`, are a list of labels.  Implement the function to return the list of labels as One-Hot encoded Numpy array.  The possible values for labels are 0 to 9. The one-hot encoding function should return the same encoding for each value between each call to `one_hot_encode`.  Make sure to save the map of encodings outside the function.
#
# Hint: Don't reinvent the wheel.

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    return np.eye(10)[x]


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### Randomize Data
# As you saw from exploring the data above, the order of the samples are randomized.  It doesn't hurt to randomize it again, but you don't need to for this dataset.

# %% [markdown]
# ## Preprocess all the data and save it
# Running the code cell below will preprocess all the CIFAR-10 data and save it to file. The code below also uses 10% of the training data for validation.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # Check Point
# This is your first checkpoint.  If you ever decide to come back to this notebook or have to restart the notebook, you can start from here.  The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %% [markdown]
# ## Build the network
# For the neural network, you'll build each layer into a function.  Most of the code you've seen has been outside of functions. To test your code more thoroughly, we require that you put each layer in a function.  This allows us to give you better feedback and test for simple mistakes using our unittests before you submit your project.
#
# >**Note:** If you're finding it hard to dedicate enough time for this course each week, we've provided a small shortcut to this part of the project. In the next couple of problems, you'll have the option to use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages to build each layer, except the layers you build in the "Convolutional and Max Pooling Layer" section.  TF Layers is similar to Keras's and TFLearn's abstraction to layers, so it's easy to pickup.
#
# >However, if you would like to get the most out of this course, try to solve all the problems _without_ using anything from the TF Layers packages. You **can** still use classes from other packages that happen to have the same name as ones you find in TF Layers! For example, instead of using the TF Layers version of the `conv2d` class, [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d), you would want to use the TF Neural Network version of `conv2d`, [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d).
#
# Let's begin!
#
# ### Input
# The neural network needs to read the image data, one-hot encoded labels, and dropout keep probability. Implement the following functions
# * Implement `neural_net_image_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `image_shape` with batch size set to `None`.
#  * Name the TensorFlow placeholder "x" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_label_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * Set the shape using `n_classes` with batch size set to `None`.
#  * Name the TensorFlow placeholder "y" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
# * Implement `neural_net_keep_prob_input`
#  * Return a [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) for dropout keep probability.
#  * Name the TensorFlow placeholder "keep_prob" using the TensorFlow `name` parameter in the [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder).
#
# These names will be used at the end of the project to load your saved model.
#
# Note: `None` for shapes in TensorFlow allow for a dynamic size.

# %%
import tensorflow as tf
tf.reset_default_graph()
def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape = [None, image_shape[0], image_shape[1], image_shape[2]],name = 'x')


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, shape = [None, n_classes], name = 'y')


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(tf.float32, name = 'keep_prob')


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### Convolution and Max Pooling Layer
# Convolution layers have a lot of success with images. For this code cell, you should implement the function `conv2d_maxpool` to apply convolution then max pooling:
# * Create the weight and bias using `conv_ksize`, `conv_num_outputs` and the shape of `x_tensor`.
# * Apply a convolution to `x_tensor` using weight and `conv_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
# * Add bias
# * Add a nonlinear activation to the convolution.
# * Apply Max Pooling using `pool_ksize` and `pool_strides`.
#  * We recommend you use same padding, but you're welcome to use any padding.
#
# **Note:** You **can't** use [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) for **this** layer, but you can still use TensorFlow's [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) package. You may still use the shortcut option for all the **other** layers.

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    #weights = tf.Variable(tf.truncated_normal([conv_ksize[0],conv_ksize[1],x_tensor.get_shape().as_list()[3],conv_num_outputs]))
    weights = tf.Variable(tf.truncated_normal([conv_ksize[0],conv_ksize[1],x_tensor.get_shape().as_list()[3],conv_num_outputs], stddev=0.1))
    #bias = tf.Variable(tf.zeros([conv_num_outputs]))
    bias = tf.Variable(tf.random_uniform([conv_num_outputs], -0.1, 0.1))
    x_tensor = tf.nn.conv2d(x_tensor, weights, strides = [1,conv_strides[0], conv_strides[1], 1], padding = 'SAME')
    x_tensor = tf.nn.bias_add(x_tensor, bias)
    x_tensor = tf.nn.relu(x_tensor)
    x_tensor = tf.nn.max_pool(x_tensor, ksize = [1, pool_ksize[0], pool_ksize[1], 1], strides = [1, pool_strides[0], pool_strides[1], 1], padding = 'SAME')
    return x_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# Tests Passed

# %% [markdown]
# ### Flatten Layer
# Implement the `flatten` function to change the dimension of `x_tensor` from a 4-D tensor to a 2-D tensor.  The output should be the shape (*Batch Size*, *Flattened Image Size*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    size = x_tensor.get_shape().as_list()
    x_tensor = tf.reshape(x_tensor, [-1,size[1]*size[2]*size[3]])
    return x_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# Tests Passed

# %% [markdown]
# ### Fully-Connected Layer
# Implement the `fully_conn` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    #flatten_weights = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1], num_outputs]))
    flatten_weights = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1], num_outputs], stddev = 0.1))
    #flatten_bias = tf.Variable(tf.zeros([num_outputs]))
    flatten_bias = tf.Variable(tf.random_uniform([num_outputs], -0.1, 0.1))
    x_tensor = tf.add(tf.matmul(x_tensor, flatten_weights), flatten_bias)
    x_tensor = tf.nn.relu(x_tensor)
    return x_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### Output Layer
# Implement the `output` function to apply a fully connected layer to `x_tensor` with the shape (*Batch Size*, *num_outputs*). Shortcut option: you can use classes from the [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) or [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) packages for this layer. For more of a challenge, only use other TensorFlow packages.
#
# **Note:** Activation, softmax, or cross entropy should **not** be applied to this.

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    #out_weights = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1], num_outputs]))
    out_weights = tf.Variable(tf.truncated_normal([x_tensor.get_shape().as_list()[1], num_outputs], stddev = 0.1))
    #out_bias = tf.Variable(tf.zeros([num_outputs]))
    out_bias = tf.Variable(tf.random_uniform([num_outputs], -0.1, 0.1))
    x_tensor = tf.add(tf.matmul(x_tensor, out_weights), out_bias)
    #x_tensor = tf.nn.relu(x_tensor)
    return x_tensor


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### Create Convolutional Model
# Implement the function `conv_net` to create a convolutional neural network model. The function takes in a batch of images, `x`, and outputs logits.  Use the layers you created above to create this model:
#
# * Apply 1, 2, or 3 Convolution and Max Pool layers
# * Apply a Flatten Layer
# * Apply 1, 2, or 3 Fully Connected Layers
# * Apply an Output Layer
# * Return the output
# * Apply [TensorFlow's Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout) to one or more layers in the model using `keep_prob`.

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    n_classes = 10
    fully_output = 1024

    #Layer1
    conv_num_outputs1 = 8
    conv_ksize1 = (4,4)
    conv_strides1 = (1, 1)
    pool_ksize1 = (2,2)
    pool_strides1 = (2,2)
    
    conv1 = conv2d_maxpool(x, conv_num_outputs1, conv_ksize1, conv_strides1, pool_ksize1, pool_strides1)
    #conv1 = tf.nn.dropout(conv1, keep_prob)
    #Layer2
    conv_num_outputs2 = 16
    conv_ksize2 = (4,4)
    conv_strides2 = (1, 1)
    pool_ksize2 = (2,2)
    pool_strides2 = (2,2)
    
    conv2 = conv2d_maxpool(conv1, conv_num_outputs2, conv_ksize2, conv_strides2, pool_ksize2, pool_strides2)
    conv2 = tf.nn.dropout(conv2, keep_prob)
    #conv3
    conv_num_outputs3 = 32
    conv_ksize3 = (4, 4)
    conv_strides3 = (1, 1)
    pool_ksize3 = (2,2)
    pool_strides3 = (2,2)
    
    conv3 = conv2d_maxpool(conv2, conv_num_outputs3, conv_ksize3, conv_strides3, pool_ksize3, pool_strides3)
    conv3 = tf.nn.dropout(conv3, keep_prob)
    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    
    conv3 = flatten(conv3)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    flat = fully_conn(conv3, fully_output)
    flat = tf.nn.dropout(flat, keep_prob)
    flat = fully_conn(flat, fully_output)
    flat = tf.nn.dropout(flat, keep_prob)
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    
    logits = output(flat, n_classes)
    
    # TODO: return output
    return logits


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# Neural Network Built!

# %% [markdown]
# ## Train the Neural Network
# ### Single Optimization
# Implement the function `train_neural_network` to do a single optimization.  The optimization should use `optimizer` to optimize in `session` with a `feed_dict` of the following:
# * `x` for image input
# * `y` for labels
# * `keep_prob` for keep probability for dropout
#
# This function will be called for each batch, so `tf.global_variables_initializer()` has already been called.
#
# Note: Nothing needs to be returned. This function is only optimizing the neural network.

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    # Initializing the variables
    session.run(optimizer, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: keep_probability})


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### Show Stats
# Implement the function `print_stats` to print loss and validation accuracy.  Use the global variables `valid_features` and `valid_labels` to calculate validation accuracy.  Use a keep probability of `1.0` to calculate the loss and validation accuracy.

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    loss = sess.run(cost, feed_dict={
                x: feature_batch,
                y: label_batch,
                keep_prob: 1.})
    valid_acc = sess.run(accuracy, feed_dict={
                x: valid_features,
                y: valid_labels,
                keep_prob: 1.})
    print('Loss: {:>10.4f} Validation Accuracy: {:.6f}'.format(
                loss,
                valid_acc))

# %% [markdown]
# ### Hyperparameters
# Tune the following parameters:
# * Set `epochs` to the number of iterations until the network stops learning or start overfitting
# * Set `batch_size` to the highest number that your machine has memory for.  Most people set them to common sizes of memory:
#  * 64
#  * 128
#  * 256
#  * ...
# * Set `keep_probability` to the probability of keeping a node using dropout

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 1024
keep_probability = 0.7

# %% [markdown]
# ### Train on a Single CIFAR-10 Batch
# Instead of training the neural network on all the CIFAR-10 batches of data, let's use a single batch. This should save time while you iterate on the model to get a better accuracy.  Once the final validation accuracy is 50% or greater, run the model on all the data in the next section.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
init = tf.global_variables_initializer()
config = tf.ConfigProto()
#config.gpu_options.allow_growth = True
config.gpu_options.per_process_gpu_memory_fraction = 0.3
with tf.Session(config=config) as sess:
    # Initializing the variables
    sess.run(init)
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        #print(batch_i + 1)
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)

# %% [markdown]
# ### Fully Train the Model
# Now that you got a good accuracy with a single CIFAR-10 batch, try it with all five batches.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'
init = tf.global_variables_initializer()
config = tf.ConfigProto()
#config.gpu_options.allow_growth = True
config.gpu_options.per_process_gpu_memory_fraction = 0.5
print('Training...')
with tf.Session(config=config) as sess:
    # Initializing the variables
    sess.run(init)
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  Loss:     2.3093 Validation Accuracy: 0.112400
# Epoch  1, CIFAR-10 Batch 2:  Loss:     2.2587 Validation Accuracy: 0.116600
# Epoch  1, CIFAR-10 Batch 3:  Loss:     2.1676 Validation Accuracy: 0.252800
# Epoch  1, CIFAR-10 Batch 4:  Loss:     2.0063 Validation Accuracy: 0.283800
# Epoch  1, CIFAR-10 Batch 5:  Loss:     1.9632 Validation Accuracy: 0.279000
# Epoch  2, CIFAR-10 Batch 1:  Loss:     1.9035 Validation Accuracy: 0.317400
# Epoch  2, CIFAR-10 Batch 2:  Loss:     1.8879 Validation Accuracy: 0.315800
# Epoch  2, CIFAR-10 Batch 3:  Loss:     1.7951 Validation Accuracy: 0.345200
# Epoch  2, CIFAR-10 Batch 4:  Loss:     1.7714 Validation Accuracy: 0.368400
# Epoch  2, CIFAR-10 Batch 5:  Loss:     1.7393 Validation Accuracy: 0.380800
# Epoch  3, CIFAR-10 Batch 1:  Loss:     1.7397 Validation Accuracy: 0.380600
# Epoch  3, CIFAR-10 Batch 2:  Loss:     1.6978 Validation Accuracy: 0.390800
# Epoch  3, CIFAR-10 Batch 3:  Loss:     1.6320 Validation Accuracy: 0.407400
# Epoch  3, CIFAR-10 Batch 4:  Loss:     1.6318 Validation Accuracy: 0.417800
# Epoch  3, CIFAR-10 Batch 5:  Loss:     1.6318 Validation Accuracy: 0.416200
# Epoch  4, CIFAR-10 Batch 1:  Loss:     1.6574 Validation Accuracy: 0.412800
# Epoch  4, CIFAR-10 Batch 2:  Loss:     1.6310 Validation Accuracy: 0.418200
# Epoch  4, CIFAR-10 Batch 3:  Loss:     1.5407 Validation Accuracy: 0.437000
# Epoch  4, CIFAR-10 Batch 4:  Loss:     1.5440 Validation Accuracy: 0.436200
# Epoch  4, CIFAR-10 Batch 5:  Loss:     1.5591 Validation Accuracy: 0.439000
# Epoch  5, CIFAR-10 Batch 1:  Loss:     1.5552 Validation Accuracy: 0.449800
# Epoch  5, CIFAR-10 Batch 2:  Loss:     1.5476 Validation Accuracy: 0.446200
# Epoch  5, CIFAR-10 Batch 3:  Loss:     1.4955 Validation Accuracy: 0.450200
# Epoch  5, CIFAR-10 Batch 4:  Loss:     1.4760 Validation Accuracy: 0.455600
# Epoch  5, CIFAR-10 Batch 5:  Loss:     1.5009 Validation Accuracy: 0.453200
# Epoch  6, CIFAR-10 Batch 1:  Loss:     1.5077 Validation Accuracy: 0.464600
# Epoch  6, CIFAR-10 Batch 2:  Loss:     1.4966 Validation Accuracy: 0.470600
# Epoch  6, CIFAR-10 Batch 3:  Loss:     1.4676 Validation Accuracy: 0.454400
# Epoch  6, CIFAR-10 Batch 4:  Loss:     1.4345 Validation Accuracy: 0.468200
# Epoch  6, CIFAR-10 Batch 5:  Loss:     1.4564 Validation Accuracy: 0.463800
# Epoch  7, CIFAR-10 Batch 1:  Loss:     1.4461 Validation Accuracy: 0.488200
# Epoch  7, CIFAR-10 Batch 2:  Loss:     1.4389 Validation Accuracy: 0.484400
# Epoch  7, CIFAR-10 Batch 3:  Loss:     1.4155 Validation Accuracy: 0.476000
# Epoch  7, CIFAR-10 Batch 4:  Loss:     1.3907 Validation Accuracy: 0.482600
# Epoch  7, CIFAR-10 Batch 5:  Loss:     1.4106 Validation Accuracy: 0.479400
# Epoch  8, CIFAR-10 Batch 1:  Loss:     1.4118 Validation Accuracy: 0.501600
# Epoch  8, CIFAR-10 Batch 2:  Loss:     1.3954 Validation Accuracy: 0.497800
# Epoch  8, CIFAR-10 Batch 3:  Loss:     1.3836 Validation Accuracy: 0.480400
# Epoch  8, CIFAR-10 Batch 4:  Loss:     1.3550 Validation Accuracy: 0.493400
# Epoch  8, CIFAR-10 Batch 5:  Loss:     1.3596 Validation Accuracy: 0.491800
# Epoch  9, CIFAR-10 Batch 1:  Loss:     1.3686 Validation Accuracy: 0.508400
# Epoch  9, CIFAR-10 Batch 2:  Loss:     1.3679 Validation Accuracy: 0.500400
# Epoch  9, CIFAR-10 Batch 3:  Loss:     1.3638 Validation Accuracy: 0.489600
# Epoch  9, CIFAR-10 Batch 4:  Loss:     1.3235 Validation Accuracy: 0.506200
# Epoch  9, CIFAR-10 Batch 5:  Loss:     1.3378 Validation Accuracy: 0.498600
# Epoch 10, CIFAR-10 Batch 1:  Loss:     1.3392 Validation Accuracy: 0.518200
# Epoch 10, CIFAR-10 Batch 2:  Loss:     1.3281 Validation Accuracy: 0.524000
# Epoch 10, CIFAR-10 Batch 3:  Loss:     1.3085 Validation Accuracy: 0.504600
# Epoch 10, CIFAR-10 Batch 4:  Loss:     1.2894 Validation Accuracy: 0.512400
# Epoch 10, CIFAR-10 Batch 5:  Loss:     1.3106 Validation Accuracy: 0.502600
# Epoch 11, CIFAR-10 Batch 1:  Loss:     1.3129 Validation Accuracy: 0.527400
# Epoch 11, CIFAR-10 Batch 2:  Loss:     1.3104 Validation Accuracy: 0.525200
# Epoch 11, CIFAR-10 Batch 3:  Loss:     1.3002 Validation Accuracy: 0.512600
# Epoch 11, CIFAR-10 Batch 4:  Loss:     1.2978 Validation Accuracy: 0.508400
# Epoch 11, CIFAR-10 Batch 5:  Loss:     1.2340 Validation Accuracy: 0.532400
# Epoch 12, CIFAR-10 Batch 1:  Loss:     1.2695 Validation Accuracy: 0.537200
# Epoch 12, CIFAR-10 Batch 2:  Loss:     1.2623 Validation Accuracy: 0.537200
# Epoch 12, CIFAR-10 Batch 3:  Loss:     1.2809 Validation Accuracy: 0.516800
# Epoch 12, CIFAR-10 Batch 4:  Loss:     1.2467 Validation Accuracy: 0.523000
# Epoch 12, CIFAR-10 Batch 5:  Loss:     1.2117 Validation Accuracy: 0.535600
# Epoch 13, CIFAR-10 Batch 1:  Loss:     1.2463 Validation Accuracy: 0.542600
# Epoch 13, CIFAR-10 Batch 2:  Loss:     1.2909 Validation Accuracy: 0.533000
# Epoch 13, CIFAR-10 Batch 3:  Loss:     1.2850 Validation Accuracy: 0.513000
# Epoch 13, CIFAR-10 Batch 4:  Loss:     1.2092 Validation Accuracy: 0.541200
# Epoch 13, CIFAR-10 Batch 5:  Loss:     1.1957 Validation Accuracy: 0.539400
# Epoch 14, CIFAR-10 Batch 1:  Loss:     1.2272 Validation Accuracy: 0.545200
# Epoch 14, CIFAR-10 Batch 2:  Loss:     1.2164 Validation Accuracy: 0.548000
# Epoch 14, CIFAR-10 Batch 3:  Loss:     1.2353 Validation Accuracy: 0.527000
# Epoch 14, CIFAR-10 Batch 4:  Loss:     1.2123 Validation Accuracy: 0.537000
# Epoch 14, CIFAR-10 Batch 5:  Loss:     1.1907 Validation Accuracy: 0.535400
# Epoch 15, CIFAR-10 Batch 1:  Loss:     1.1892 Validation Accuracy: 0.556600
# Epoch 15, CIFAR-10 Batch 2:  Loss:     1.2030 Validation Accuracy: 0.550200
# Epoch 15, CIFAR-10 Batch 3:  Loss:     1.2080 Validation Accuracy: 0.544800
# Epoch 15, CIFAR-10 Batch 4:  Loss:     1.1539 Validation Accuracy: 0.553000
# Epoch 15, CIFAR-10 Batch 5:  Loss:     1.1274 Validation Accuracy: 0.556800
# Epoch 16, CIFAR-10 Batch 1:  Loss:     1.1640 Validation Accuracy: 0.562800
# Epoch 16, CIFAR-10 Batch 2:  Loss:     1.2019 Validation Accuracy: 0.553400
# Epoch 16, CIFAR-10 Batch 3:  Loss:     1.2340 Validation Accuracy: 0.530800
# Epoch 16, CIFAR-10 Batch 4:  Loss:     1.1397 Validation Accuracy: 0.563400
# Epoch 16, CIFAR-10 Batch 5:  Loss:     1.1260 Validation Accuracy: 0.550400
# Epoch 17, CIFAR-10 Batch 1:  Loss:     1.1499 Validation Accuracy: 0.567200
# Epoch 17, CIFAR-10 Batch 2:  Loss:     1.1996 Validation Accuracy: 0.554600
# Epoch 17, CIFAR-10 Batch 3:  Loss:     1.1451 Validation Accuracy: 0.555400
# Epoch 17, CIFAR-10 Batch 4:  Loss:     1.1299 Validation Accuracy: 0.563800
# Epoch 17, CIFAR-10 Batch 5:  Loss:     1.0773 Validation Accuracy: 0.563200
# Epoch 18, CIFAR-10 Batch 1:  Loss:     1.1262 Validation Accuracy: 0.572400
# Epoch 18, CIFAR-10 Batch 2:  Loss:     1.1592 Validation Accuracy: 0.564600
# Epoch 18, CIFAR-10 Batch 3:  Loss:     1.1405 Validation Accuracy: 0.556200
# Epoch 18, CIFAR-10 Batch 4:  Loss:     1.1123 Validation Accuracy: 0.569800
# Epoch 18, CIFAR-10 Batch 5:  Loss:     1.0649 Validation Accuracy: 0.562400
# Epoch 19, CIFAR-10 Batch 1:  Loss:     1.1205 Validation Accuracy: 0.581200
# Epoch 19, CIFAR-10 Batch 2:  Loss:     1.1443 Validation Accuracy: 0.570400
# Epoch 19, CIFAR-10 Batch 3:  Loss:     1.1273 Validation Accuracy: 0.558600
# Epoch 19, CIFAR-10 Batch 4:  Loss:     1.1012 Validation Accuracy: 0.572400
# Epoch 19, CIFAR-10 Batch 5:  Loss:     1.0369 Validation Accuracy: 0.570400
# Epoch 20, CIFAR-10 Batch 1:  Loss:     1.0634 Validation Accuracy: 0.591200
# Epoch 20, CIFAR-10 Batch 2:  Loss:     1.1500 Validation Accuracy: 0.565600
# Epoch 20, CIFAR-10 Batch 3:  Loss:     1.0770 Validation Accuracy: 0.570800
# Epoch 20, CIFAR-10 Batch 4:  Loss:     1.0569 Validation Accuracy: 0.587200
# Epoch 20, CIFAR-10 Batch 5:  Loss:     1.0302 Validation Accuracy: 0.572400
# Epoch 21, CIFAR-10 Batch 1:  Loss:     1.0587 Validation Accuracy: 0.591400
# Epoch 21, CIFAR-10 Batch 2:  Loss:     1.0800 Validation Accuracy: 0.595000
# Epoch 21, CIFAR-10 Batch 3:  Loss:     1.0845 Validation Accuracy: 0.575400
# Epoch 21, CIFAR-10 Batch 4:  Loss:     1.0434 Validation Accuracy: 0.592800
# Epoch 21, CIFAR-10 Batch 5:  Loss:     0.9958 Validation Accuracy: 0.583800
# Epoch 22, CIFAR-10 Batch 1:  Loss:     1.0250 Validation Accuracy: 0.600600
# Epoch 22, CIFAR-10 Batch 2:  Loss:     1.0620 Validation Accuracy: 0.597800
# Epoch 22, CIFAR-10 Batch 3:  Loss:     1.0897 Validation Accuracy: 0.574600
# Epoch 22, CIFAR-10 Batch 4:  Loss:     1.0051 Validation Accuracy: 0.596200
# Epoch 22, CIFAR-10 Batch 5:  Loss:     0.9629 Validation Accuracy: 0.592800
# Epoch 23, CIFAR-10 Batch 1:  Loss:     1.0105 Validation Accuracy: 0.605600
# Epoch 23, CIFAR-10 Batch 2:  Loss:     1.0731 Validation Accuracy: 0.596200
# Epoch 23, CIFAR-10 Batch 3:  Loss:     1.0561 Validation Accuracy: 0.585200
# Epoch 23, CIFAR-10 Batch 4:  Loss:     1.0000 Validation Accuracy: 0.597400
# Epoch 23, CIFAR-10 Batch 5:  Loss:     0.9418 Validation Accuracy: 0.595400
# Epoch 24, CIFAR-10 Batch 1:  Loss:     0.9939 Validation Accuracy: 0.607000
# Epoch 24, CIFAR-10 Batch 2:  Loss:     1.0580 Validation Accuracy: 0.599600
# Epoch 24, CIFAR-10 Batch 3:  Loss:     0.9996 Validation Accuracy: 0.599600
# Epoch 24, CIFAR-10 Batch 4:  Loss:     0.9705 Validation Accuracy: 0.603200
# Epoch 24, CIFAR-10 Batch 5:  Loss:     0.9428 Validation Accuracy: 0.591600
# Epoch 25, CIFAR-10 Batch 1:  Loss:     0.9735 Validation Accuracy: 0.614800
# Epoch 25, CIFAR-10 Batch 2:  Loss:     1.0011 Validation Accuracy: 0.607400
# Epoch 25, CIFAR-10 Batch 3:  Loss:     0.9933 Validation Accuracy: 0.601000
# Epoch 25, CIFAR-10 Batch 4:  Loss:     0.9947 Validation Accuracy: 0.600000
# Epoch 25, CIFAR-10 Batch 5:  Loss:     0.9218 Validation Accuracy: 0.601600
# Epoch 26, CIFAR-10 Batch 1:  Loss:     0.9477 Validation Accuracy: 0.620200
# Epoch 26, CIFAR-10 Batch 2:  Loss:     1.0246 Validation Accuracy: 0.603400
# Epoch 26, CIFAR-10 Batch 3:  Loss:     0.9823 Validation Accuracy: 0.605400
# Epoch 26, CIFAR-10 Batch 4:  Loss:     0.9710 Validation Accuracy: 0.603400
# Epoch 26, CIFAR-10 Batch 5:  Loss:     0.9046 Validation Accuracy: 0.606000
# Epoch 27, CIFAR-10 Batch 1:  Loss:     0.9215 Validation Accuracy: 0.622200
# Epoch 27, CIFAR-10 Batch 2:  Loss:     1.0105 Validation Accuracy: 0.608800
# Epoch 27, CIFAR-10 Batch 3:  Loss:     0.9612 Validation Accuracy: 0.613400
# Epoch 27, CIFAR-10 Batch 4:  Loss:     0.9316 Validation Accuracy: 0.611800
# Epoch 27, CIFAR-10 Batch 5:  Loss:     0.8515 Validation Accuracy: 0.618200
# Epoch 28, CIFAR-10 Batch 1:  Loss:     0.9074 Validation Accuracy: 0.623200
# Epoch 28, CIFAR-10 Batch 2:  Loss:     0.9458 Validation Accuracy: 0.617600
# Epoch 28, CIFAR-10 Batch 3:  Loss:     0.9732 Validation Accuracy: 0.606000
# Epoch 28, CIFAR-10 Batch 4:  Loss:     0.9047 Validation Accuracy: 0.622600
# Epoch 28, CIFAR-10 Batch 5:  Loss:     0.8552 Validation Accuracy: 0.619200
# Epoch 29, CIFAR-10 Batch 1:  Loss:     0.8858 Validation Accuracy: 0.630800
# Epoch 29, CIFAR-10 Batch 2:  Loss:     0.9499 Validation Accuracy: 0.620600
# Epoch 29, CIFAR-10 Batch 3:  Loss:     0.9058 Validation Accuracy: 0.630200
# Epoch 29, CIFAR-10 Batch 4:  Loss:     0.9124 Validation Accuracy: 0.619800
# Epoch 29, CIFAR-10 Batch 5:  Loss:     0.8473 Validation Accuracy: 0.614200
# Epoch 30, CIFAR-10 Batch 1:  Loss:     0.8836 Validation Accuracy: 0.634000
# Epoch 30, CIFAR-10 Batch 2:  Loss:     0.9629 Validation Accuracy: 0.615200
# Epoch 30, CIFAR-10 Batch 3:  Loss:     0.9244 Validation Accuracy: 0.620000
# Epoch 30, CIFAR-10 Batch 4:  Loss:     0.8698 Validation Accuracy: 0.628200
# Epoch 30, CIFAR-10 Batch 5:  Loss:     0.8284 Validation Accuracy: 0.626600
# Epoch 31, CIFAR-10 Batch 1:  Loss:     0.8577 Validation Accuracy: 0.636000
# Epoch 31, CIFAR-10 Batch 2:  Loss:     0.9034 Validation Accuracy: 0.630400
# Epoch 31, CIFAR-10 Batch 3:  Loss:     0.9408 Validation Accuracy: 0.611400
# Epoch 31, CIFAR-10 Batch 4:  Loss:     0.8703 Validation Accuracy: 0.631200
# Epoch 31, CIFAR-10 Batch 5:  Loss:     0.7984 Validation Accuracy: 0.630200
# Epoch 32, CIFAR-10 Batch 1:  Loss:     0.8432 Validation Accuracy: 0.638800
# Epoch 32, CIFAR-10 Batch 2:  Loss:     0.9389 Validation Accuracy: 0.612400
# Epoch 32, CIFAR-10 Batch 3:  Loss:     0.8581 Validation Accuracy: 0.636200
# Epoch 32, CIFAR-10 Batch 4:  Loss:     0.8630 Validation Accuracy: 0.627600
# Epoch 32, CIFAR-10 Batch 5:  Loss:     0.8068 Validation Accuracy: 0.626800
# Epoch 33, CIFAR-10 Batch 1:  Loss:     0.8269 Validation Accuracy: 0.639600
# Epoch 33, CIFAR-10 Batch 2:  Loss:     0.8645 Validation Accuracy: 0.636600
# Epoch 33, CIFAR-10 Batch 3:  Loss:     0.8853 Validation Accuracy: 0.630800
# Epoch 33, CIFAR-10 Batch 4:  Loss:     0.8531 Validation Accuracy: 0.632600
# Epoch 33, CIFAR-10 Batch 5:  Loss:     0.7682 Validation Accuracy: 0.634000
# Epoch 34, CIFAR-10 Batch 1:  Loss:     0.8171 Validation Accuracy: 0.639400
# Epoch 34, CIFAR-10 Batch 2:  Loss:     0.8958 Validation Accuracy: 0.626000
# Epoch 34, CIFAR-10 Batch 3:  Loss:     0.8572 Validation Accuracy: 0.633000
# Epoch 34, CIFAR-10 Batch 4:  Loss:     0.8320 Validation Accuracy: 0.633800
# Epoch 34, CIFAR-10 Batch 5:  Loss:     0.7700 Validation Accuracy: 0.631800
# Epoch 35, CIFAR-10 Batch 1:  Loss:     0.7959 Validation Accuracy: 0.645000
# Epoch 35, CIFAR-10 Batch 2:  Loss:     0.8797 Validation Accuracy: 0.632400
# Epoch 35, CIFAR-10 Batch 3:  Loss:     0.8618 Validation Accuracy: 0.631200
# Epoch 35, CIFAR-10 Batch 4:  Loss:     0.8322 Validation Accuracy: 0.633600
# Epoch 35, CIFAR-10 Batch 5:  Loss:     0.7433 Validation Accuracy: 0.631200
# Epoch 36, CIFAR-10 Batch 1:  Loss:     0.7772 Validation Accuracy: 0.651800
# Epoch 36, CIFAR-10 Batch 2:  Loss:     0.8394 Validation Accuracy: 0.641600
# Epoch 36, CIFAR-10 Batch 3:  Loss:     0.8305 Validation Accuracy: 0.635000
# Epoch 36, CIFAR-10 Batch 4:  Loss:     0.8161 Validation Accuracy: 0.638600
# Epoch 36, CIFAR-10 Batch 5:  Loss:     0.7360 Validation Accuracy: 0.638200
# Epoch 37, CIFAR-10 Batch 1:  Loss:     0.7705 Validation Accuracy: 0.656200
# Epoch 37, CIFAR-10 Batch 2:  Loss:     0.8353 Validation Accuracy: 0.636800
# Epoch 37, CIFAR-10 Batch 3:  Loss:     0.8246 Validation Accuracy: 0.640200
# Epoch 37, CIFAR-10 Batch 4:  Loss:     0.7682 Validation Accuracy: 0.642200
# Epoch 37, CIFAR-10 Batch 5:  Loss:     0.7114 Validation Accuracy: 0.642600
# Epoch 38, CIFAR-10 Batch 1:  Loss:     0.7610 Validation Accuracy: 0.649800
# Epoch 38, CIFAR-10 Batch 2:  Loss:     0.8354 Validation Accuracy: 0.635000
# Epoch 38, CIFAR-10 Batch 3:  Loss:     0.7891 Validation Accuracy: 0.643800
# Epoch 38, CIFAR-10 Batch 4:  Loss:     0.7754 Validation Accuracy: 0.648400
# Epoch 38, CIFAR-10 Batch 5:  Loss:     0.7123 Validation Accuracy: 0.637400
# Epoch 39, CIFAR-10 Batch 1:  Loss:     0.7530 Validation Accuracy: 0.654200
# Epoch 39, CIFAR-10 Batch 2:  Loss:     0.7889 Validation Accuracy: 0.646000
# Epoch 39, CIFAR-10 Batch 3:  Loss:     0.7948 Validation Accuracy: 0.640600
# Epoch 39, CIFAR-10 Batch 4:  Loss:     0.7586 Validation Accuracy: 0.645400
# Epoch 39, CIFAR-10 Batch 5:  Loss:     0.6928 Validation Accuracy: 0.645400
# Epoch 40, CIFAR-10 Batch 1:  Loss:     0.7255 Validation Accuracy: 0.654600
# Epoch 40, CIFAR-10 Batch 2:  Loss:     0.7848 Validation Accuracy: 0.651600
# Epoch 40, CIFAR-10 Batch 3:  Loss:     0.7665 Validation Accuracy: 0.655000
# Epoch 40, CIFAR-10 Batch 4:  Loss:     0.7400 Validation Accuracy: 0.650200
# Epoch 40, CIFAR-10 Batch 5:  Loss:     0.6823 Validation Accuracy: 0.650000
# Epoch 41, CIFAR-10 Batch 1:  Loss:     0.7251 Validation Accuracy: 0.659800
# Epoch 41, CIFAR-10 Batch 2:  Loss:     0.7688 Validation Accuracy: 0.654200
# Epoch 41, CIFAR-10 Batch 3:  Loss:     0.7501 Validation Accuracy: 0.649000
# Epoch 41, CIFAR-10 Batch 4:  Loss:     0.7622 Validation Accuracy: 0.643800
# Epoch 41, CIFAR-10 Batch 5:  Loss:     0.6611 Validation Accuracy: 0.644000
# Epoch 42, CIFAR-10 Batch 1:  Loss:     0.7064 Validation Accuracy: 0.660400
# Epoch 42, CIFAR-10 Batch 2:  Loss:     0.7806 Validation Accuracy: 0.647400
# Epoch 42, CIFAR-10 Batch 3:  Loss:     0.7339 Validation Accuracy: 0.651600
# Epoch 42, CIFAR-10 Batch 4:  Loss:     0.7247 Validation Accuracy: 0.648600
# Epoch 42, CIFAR-10 Batch 5:  Loss:     0.6559 Validation Accuracy: 0.649200
# Epoch 43, CIFAR-10 Batch 1:  Loss:     0.6878 Validation Accuracy: 0.662600
# Epoch 43, CIFAR-10 Batch 2:  Loss:     0.7521 Validation Accuracy: 0.647200
# Epoch 43, CIFAR-10 Batch 3:  Loss:     0.7355 Validation Accuracy: 0.653000
# Epoch 43, CIFAR-10 Batch 4:  Loss:     0.7057 Validation Accuracy: 0.654600
# Epoch 43, CIFAR-10 Batch 5:  Loss:     0.6480 Validation Accuracy: 0.650800
# Epoch 44, CIFAR-10 Batch 1:  Loss:     0.6699 Validation Accuracy: 0.663400
# Epoch 44, CIFAR-10 Batch 2:  Loss:     0.7288 Validation Accuracy: 0.661600
# Epoch 44, CIFAR-10 Batch 3:  Loss:     0.7157 Validation Accuracy: 0.649600
# Epoch 44, CIFAR-10 Batch 4:  Loss:     0.6874 Validation Accuracy: 0.662000
# Epoch 44, CIFAR-10 Batch 5:  Loss:     0.6274 Validation Accuracy: 0.652800
# Epoch 45, CIFAR-10 Batch 1:  Loss:     0.6709 Validation Accuracy: 0.663400
# Epoch 45, CIFAR-10 Batch 2:  Loss:     0.7491 Validation Accuracy: 0.654800
# Epoch 45, CIFAR-10 Batch 3:  Loss:     0.6935 Validation Accuracy: 0.658000
# Epoch 45, CIFAR-10 Batch 4:  Loss:     0.6836 Validation Accuracy: 0.657800
# Epoch 45, CIFAR-10 Batch 5:  Loss:     0.6386 Validation Accuracy: 0.654600
# Epoch 46, CIFAR-10 Batch 1:  Loss:     0.6649 Validation Accuracy: 0.663200
# Epoch 46, CIFAR-10 Batch 2:  Loss:     0.7132 Validation Accuracy: 0.665000
# Epoch 46, CIFAR-10 Batch 3:  Loss:     0.6828 Validation Accuracy: 0.659200
# Epoch 46, CIFAR-10 Batch 4:  Loss:     0.6874 Validation Accuracy: 0.660400
# Epoch 46, CIFAR-10 Batch 5:  Loss:     0.6031 Validation Accuracy: 0.659800
# Epoch 47, CIFAR-10 Batch 1:  Loss:     0.6427 Validation Accuracy: 0.666000
# Epoch 47, CIFAR-10 Batch 2:  Loss:     0.7109 Validation Accuracy: 0.662000
# Epoch 47, CIFAR-10 Batch 3:  Loss:     0.6852 Validation Accuracy: 0.655600
# Epoch 47, CIFAR-10 Batch 4:  Loss:     0.6354 Validation Accuracy: 0.665400
# Epoch 47, CIFAR-10 Batch 5:  Loss:     0.6046 Validation Accuracy: 0.652200
# Epoch 48, CIFAR-10 Batch 1:  Loss:     0.6334 Validation Accuracy: 0.669400
# Epoch 48, CIFAR-10 Batch 2:  Loss:     0.7004 Validation Accuracy: 0.663400
# Epoch 48, CIFAR-10 Batch 3:  Loss:     0.6855 Validation Accuracy: 0.658800
# Epoch 48, CIFAR-10 Batch 4:  Loss:     0.6356 Validation Accuracy: 0.666600
# Epoch 48, CIFAR-10 Batch 5:  Loss:     0.6097 Validation Accuracy: 0.652800
# Epoch 49, CIFAR-10 Batch 1:  Loss:     0.6266 Validation Accuracy: 0.671400
# Epoch 49, CIFAR-10 Batch 2:  Loss:     0.6765 Validation Accuracy: 0.669600
# Epoch 49, CIFAR-10 Batch 3:  Loss:     0.6765 Validation Accuracy: 0.655800
# Epoch 49, CIFAR-10 Batch 4:  Loss:     0.6640 Validation Accuracy: 0.661000
# Epoch 49, CIFAR-10 Batch 5:  Loss:     0.5809 Validation Accuracy: 0.662000
# Epoch 50, CIFAR-10 Batch 1:  Loss:     0.6183 Validation Accuracy: 0.673400
# Epoch 50, CIFAR-10 Batch 2:  Loss:     0.6778 Validation Accuracy: 0.668400
# Epoch 50, CIFAR-10 Batch 3:  Loss:     0.6751 Validation Accuracy: 0.656200
# Epoch 50, CIFAR-10 Batch 4:  Loss:     0.6158 Validation Accuracy: 0.668200
# Epoch 50, CIFAR-10 Batch 5:  Loss:     0.5793 Validation Accuracy: 0.663000
# Epoch 51, CIFAR-10 Batch 1:  Loss:     0.6039 Validation Accuracy: 0.671000
# Epoch 51, CIFAR-10 Batch 2:  Loss:     0.7050 Validation Accuracy: 0.663400
# Epoch 51, CIFAR-10 Batch 3:  Loss:     0.6519 Validation Accuracy: 0.665800
# Epoch 51, CIFAR-10 Batch 4:  Loss:     0.6121 Validation Accuracy: 0.665800
# Epoch 51, CIFAR-10 Batch 5:  Loss:     0.5898 Validation Accuracy: 0.662000
# Epoch 52, CIFAR-10 Batch 1:  Loss:     0.6173 Validation Accuracy: 0.670000
# Epoch 52, CIFAR-10 Batch 2:  Loss:     0.6581 Validation Accuracy: 0.671400
# Epoch 52, CIFAR-10 Batch 3:  Loss:     0.6226 Validation Accuracy: 0.673800
# Epoch 52, CIFAR-10 Batch 4:  Loss:     0.6138 Validation Accuracy: 0.669000
# Epoch 52, CIFAR-10 Batch 5:  Loss:     0.5670 Validation Accuracy: 0.661600
# Epoch 53, CIFAR-10 Batch 1:  Loss:     0.5840 Validation Accuracy: 0.674000
# Epoch 53, CIFAR-10 Batch 2:  Loss:     0.6283 Validation Accuracy: 0.672800
# Epoch 53, CIFAR-10 Batch 3:  Loss:     0.6434 Validation Accuracy: 0.658600
# Epoch 53, CIFAR-10 Batch 4:  Loss:     0.5811 Validation Accuracy: 0.673400
# Epoch 53, CIFAR-10 Batch 5:  Loss:     0.5688 Validation Accuracy: 0.666000
# Epoch 54, CIFAR-10 Batch 1:  Loss:     0.5788 Validation Accuracy: 0.675600
# Epoch 54, CIFAR-10 Batch 2:  Loss:     0.6299 Validation Accuracy: 0.675800
# Epoch 54, CIFAR-10 Batch 3:  Loss:     0.6512 Validation Accuracy: 0.656200
# Epoch 54, CIFAR-10 Batch 4:  Loss:     0.5782 Validation Accuracy: 0.669600
# Epoch 54, CIFAR-10 Batch 5:  Loss:     0.6042 Validation Accuracy: 0.653200
# Epoch 55, CIFAR-10 Batch 1:  Loss:     0.5717 Validation Accuracy: 0.670200
# Epoch 55, CIFAR-10 Batch 2:  Loss:     0.6412 Validation Accuracy: 0.676800
# Epoch 55, CIFAR-10 Batch 3:  Loss:     0.6141 Validation Accuracy: 0.663800
# Epoch 55, CIFAR-10 Batch 4:  Loss:     0.5602 Validation Accuracy: 0.674000
# Epoch 55, CIFAR-10 Batch 5:  Loss:     0.5681 Validation Accuracy: 0.662600
# Epoch 56, CIFAR-10 Batch 1:  Loss:     0.5550 Validation Accuracy: 0.682400
# Epoch 56, CIFAR-10 Batch 2:  Loss:     0.6359 Validation Accuracy: 0.670800
# Epoch 56, CIFAR-10 Batch 3:  Loss:     0.6221 Validation Accuracy: 0.662800
# Epoch 56, CIFAR-10 Batch 4:  Loss:     0.5401 Validation Accuracy: 0.674000
# Epoch 56, CIFAR-10 Batch 5:  Loss:     0.5696 Validation Accuracy: 0.660400
# Epoch 57, CIFAR-10 Batch 1:  Loss:     0.5293 Validation Accuracy: 0.684000
# Epoch 57, CIFAR-10 Batch 2:  Loss:     0.6129 Validation Accuracy: 0.677200
# Epoch 57, CIFAR-10 Batch 3:  Loss:     0.5922 Validation Accuracy: 0.665400
# Epoch 57, CIFAR-10 Batch 4:  Loss:     0.5221 Validation Accuracy: 0.680000
# Epoch 57, CIFAR-10 Batch 5:  Loss:     0.5607 Validation Accuracy: 0.657600
# Epoch 58, CIFAR-10 Batch 1:  Loss:     0.5185 Validation Accuracy: 0.680200
# Epoch 58, CIFAR-10 Batch 2:  Loss:     0.6052 Validation Accuracy: 0.673200
# Epoch 58, CIFAR-10 Batch 3:  Loss:     0.6410 Validation Accuracy: 0.645800
# Epoch 58, CIFAR-10 Batch 4:  Loss:     0.5280 Validation Accuracy: 0.669800
# Epoch 58, CIFAR-10 Batch 5:  Loss:     0.5055 Validation Accuracy: 0.671400
# Epoch 59, CIFAR-10 Batch 1:  Loss:     0.5816 Validation Accuracy: 0.665200
# Epoch 59, CIFAR-10 Batch 2:  Loss:     0.5682 Validation Accuracy: 0.679400
# Epoch 59, CIFAR-10 Batch 3:  Loss:     0.5558 Validation Accuracy: 0.673200
# Epoch 59, CIFAR-10 Batch 4:  Loss:     0.5267 Validation Accuracy: 0.675200
# Epoch 59, CIFAR-10 Batch 5:  Loss:     0.5006 Validation Accuracy: 0.670000
# Epoch 60, CIFAR-10 Batch 1:  Loss:     0.5110 Validation Accuracy: 0.683400
# Epoch 60, CIFAR-10 Batch 2:  Loss:     0.5662 Validation Accuracy: 0.679000
# Epoch 60, CIFAR-10 Batch 3:  Loss:     0.5615 Validation Accuracy: 0.671000
# Epoch 60, CIFAR-10 Batch 4:  Loss:     0.5176 Validation Accuracy: 0.684400
# Epoch 60, CIFAR-10 Batch 5:  Loss:     0.5020 Validation Accuracy: 0.670400
# Epoch 61, CIFAR-10 Batch 1:  Loss:     0.5187 Validation Accuracy: 0.681200
# Epoch 61, CIFAR-10 Batch 2:  Loss:     0.5553 Validation Accuracy: 0.682800
# Epoch 61, CIFAR-10 Batch 3:  Loss:     0.5755 Validation Accuracy: 0.665800
# Epoch 61, CIFAR-10 Batch 4:  Loss:     0.5061 Validation Accuracy: 0.684800
# Epoch 61, CIFAR-10 Batch 5:  Loss:     0.4812 Validation Accuracy: 0.683200
# Epoch 62, CIFAR-10 Batch 1:  Loss:     0.5321 Validation Accuracy: 0.674000
# Epoch 62, CIFAR-10 Batch 2:  Loss:     0.5440 Validation Accuracy: 0.681200
# Epoch 62, CIFAR-10 Batch 3:  Loss:     0.5430 Validation Accuracy: 0.678200
# Epoch 62, CIFAR-10 Batch 4:  Loss:     0.5125 Validation Accuracy: 0.683400
# Epoch 62, CIFAR-10 Batch 5:  Loss:     0.4708 Validation Accuracy: 0.677200
# Epoch 63, CIFAR-10 Batch 1:  Loss:     0.4952 Validation Accuracy: 0.682600
# Epoch 63, CIFAR-10 Batch 2:  Loss:     0.5343 Validation Accuracy: 0.684600
# Epoch 63, CIFAR-10 Batch 3:  Loss:     0.5808 Validation Accuracy: 0.662400
# Epoch 63, CIFAR-10 Batch 4:  Loss:     0.5060 Validation Accuracy: 0.686200
# Epoch 63, CIFAR-10 Batch 5:  Loss:     0.4544 Validation Accuracy: 0.680800
# Epoch 64, CIFAR-10 Batch 1:  Loss:     0.5147 Validation Accuracy: 0.677800
# Epoch 64, CIFAR-10 Batch 2:  Loss:     0.5215 Validation Accuracy: 0.688400
# Epoch 64, CIFAR-10 Batch 3:  Loss:     0.5006 Validation Accuracy: 0.688000
# Epoch 64, CIFAR-10 Batch 4:  Loss:     0.5049 Validation Accuracy: 0.688200
# Epoch 64, CIFAR-10 Batch 5:  Loss:     0.4523 Validation Accuracy: 0.682800
# Epoch 65, CIFAR-10 Batch 1:  Loss:     0.4854 Validation Accuracy: 0.680000
# Epoch 65, CIFAR-10 Batch 2:  Loss:     0.5134 Validation Accuracy: 0.691400
# Epoch 65, CIFAR-10 Batch 3:  Loss:     0.5292 Validation Accuracy: 0.670000
# Epoch 65, CIFAR-10 Batch 4:  Loss:     0.4845 Validation Accuracy: 0.688600
# Epoch 65, CIFAR-10 Batch 5:  Loss:     0.4475 Validation Accuracy: 0.679600
# Epoch 66, CIFAR-10 Batch 1:  Loss:     0.4680 Validation Accuracy: 0.684400
# Epoch 66, CIFAR-10 Batch 2:  Loss:     0.5191 Validation Accuracy: 0.683400
# Epoch 66, CIFAR-10 Batch 3:  Loss:     0.5168 Validation Accuracy: 0.676800
# Epoch 66, CIFAR-10 Batch 4:  Loss:     0.4747 Validation Accuracy: 0.685600
# Epoch 66, CIFAR-10 Batch 5:  Loss:     0.4455 Validation Accuracy: 0.684800
# Epoch 67, CIFAR-10 Batch 1:  Loss:     0.4462 Validation Accuracy: 0.696200
# Epoch 67, CIFAR-10 Batch 2:  Loss:     0.5153 Validation Accuracy: 0.687400
# Epoch 67, CIFAR-10 Batch 3:  Loss:     0.5011 Validation Accuracy: 0.677000
# Epoch 67, CIFAR-10 Batch 4:  Loss:     0.4369 Validation Accuracy: 0.685800
# Epoch 67, CIFAR-10 Batch 5:  Loss:     0.4295 Validation Accuracy: 0.686000
# Epoch 68, CIFAR-10 Batch 1:  Loss:     0.4350 Validation Accuracy: 0.692000
# Epoch 68, CIFAR-10 Batch 2:  Loss:     0.4884 Validation Accuracy: 0.694600
# Epoch 68, CIFAR-10 Batch 3:  Loss:     0.4850 Validation Accuracy: 0.683800
# Epoch 68, CIFAR-10 Batch 4:  Loss:     0.4365 Validation Accuracy: 0.691800
# Epoch 68, CIFAR-10 Batch 5:  Loss:     0.4214 Validation Accuracy: 0.684000
# Epoch 69, CIFAR-10 Batch 1:  Loss:     0.4601 Validation Accuracy: 0.680400
# Epoch 69, CIFAR-10 Batch 2:  Loss:     0.4832 Validation Accuracy: 0.690400
# Epoch 69, CIFAR-10 Batch 3:  Loss:     0.5067 Validation Accuracy: 0.674600
# Epoch 69, CIFAR-10 Batch 4:  Loss:     0.4311 Validation Accuracy: 0.693000
# Epoch 69, CIFAR-10 Batch 5:  Loss:     0.4089 Validation Accuracy: 0.690200
# Epoch 70, CIFAR-10 Batch 1:  Loss:     0.4438 Validation Accuracy: 0.689800
# Epoch 70, CIFAR-10 Batch 2:  Loss:     0.4867 Validation Accuracy: 0.687200
# Epoch 70, CIFAR-10 Batch 3:  Loss:     0.4458 Validation Accuracy: 0.690400
# Epoch 70, CIFAR-10 Batch 4:  Loss:     0.4494 Validation Accuracy: 0.687000
# Epoch 70, CIFAR-10 Batch 5:  Loss:     0.4110 Validation Accuracy: 0.683000
# Epoch 71, CIFAR-10 Batch 1:  Loss:     0.4462 Validation Accuracy: 0.682200
# Epoch 71, CIFAR-10 Batch 2:  Loss:     0.4779 Validation Accuracy: 0.687400
# Epoch 71, CIFAR-10 Batch 3:  Loss:     0.4764 Validation Accuracy: 0.678400
# Epoch 71, CIFAR-10 Batch 4:  Loss:     0.4240 Validation Accuracy: 0.694400
# Epoch 71, CIFAR-10 Batch 5:  Loss:     0.4126 Validation Accuracy: 0.686400
# Epoch 72, CIFAR-10 Batch 1:  Loss:     0.4054 Validation Accuracy: 0.693600
# Epoch 72, CIFAR-10 Batch 2:  Loss:     0.4637 Validation Accuracy: 0.689200
# Epoch 72, CIFAR-10 Batch 3:  Loss:     0.4733 Validation Accuracy: 0.678400
# Epoch 72, CIFAR-10 Batch 4:  Loss:     0.4188 Validation Accuracy: 0.692600
# Epoch 72, CIFAR-10 Batch 5:  Loss:     0.3811 Validation Accuracy: 0.690000
# Epoch 73, CIFAR-10 Batch 1:  Loss:     0.4199 Validation Accuracy: 0.689400
# Epoch 73, CIFAR-10 Batch 2:  Loss:     0.4517 Validation Accuracy: 0.691200
# Epoch 73, CIFAR-10 Batch 3:  Loss:     0.4631 Validation Accuracy: 0.676200
# Epoch 73, CIFAR-10 Batch 4:  Loss:     0.4038 Validation Accuracy: 0.693400
# Epoch 73, CIFAR-10 Batch 5:  Loss:     0.4329 Validation Accuracy: 0.676200
# Epoch 74, CIFAR-10 Batch 1:  Loss:     0.3942 Validation Accuracy: 0.695600
# Epoch 74, CIFAR-10 Batch 2:  Loss:     0.4579 Validation Accuracy: 0.692600
# Epoch 74, CIFAR-10 Batch 3:  Loss:     0.4226 Validation Accuracy: 0.694000
# Epoch 74, CIFAR-10 Batch 4:  Loss:     0.4073 Validation Accuracy: 0.694000
# Epoch 74, CIFAR-10 Batch 5:  Loss:     0.3688 Validation Accuracy: 0.690200
# Epoch 75, CIFAR-10 Batch 1:  Loss:     0.4087 Validation Accuracy: 0.693600
# Epoch 75, CIFAR-10 Batch 2:  Loss:     0.4308 Validation Accuracy: 0.687400
# Epoch 75, CIFAR-10 Batch 3:  Loss:     0.4434 Validation Accuracy: 0.681800
# Epoch 75, CIFAR-10 Batch 4:  Loss:     0.3902 Validation Accuracy: 0.693800
# Epoch 75, CIFAR-10 Batch 5:  Loss:     0.3779 Validation Accuracy: 0.687800
# Epoch 76, CIFAR-10 Batch 1:  Loss:     0.3910 Validation Accuracy: 0.692800
# Epoch 76, CIFAR-10 Batch 2:  Loss:     0.4268 Validation Accuracy: 0.692800
# Epoch 76, CIFAR-10 Batch 3:  Loss:     0.4173 Validation Accuracy: 0.690600
# Epoch 76, CIFAR-10 Batch 4:  Loss:     0.3886 Validation Accuracy: 0.696200
# Epoch 76, CIFAR-10 Batch 5:  Loss:     0.3751 Validation Accuracy: 0.688800
# Epoch 77, CIFAR-10 Batch 1:  Loss:     0.3814 Validation Accuracy: 0.693400
# Epoch 77, CIFAR-10 Batch 2:  Loss:     0.4074 Validation Accuracy: 0.694600
# Epoch 77, CIFAR-10 Batch 3:  Loss:     0.4161 Validation Accuracy: 0.685200
# Epoch 77, CIFAR-10 Batch 4:  Loss:     0.3857 Validation Accuracy: 0.696800
# Epoch 77, CIFAR-10 Batch 5:  Loss:     0.3817 Validation Accuracy: 0.692200
# Epoch 78, CIFAR-10 Batch 1:  Loss:     0.3606 Validation Accuracy: 0.698600
# Epoch 78, CIFAR-10 Batch 2:  Loss:     0.4344 Validation Accuracy: 0.690800
# Epoch 78, CIFAR-10 Batch 3:  Loss:     0.4048 Validation Accuracy: 0.689400
# Epoch 78, CIFAR-10 Batch 4:  Loss:     0.3770 Validation Accuracy: 0.700600
# Epoch 78, CIFAR-10 Batch 5:  Loss:     0.3773 Validation Accuracy: 0.686200
# Epoch 79, CIFAR-10 Batch 1:  Loss:     0.3604 Validation Accuracy: 0.698000
# Epoch 79, CIFAR-10 Batch 2:  Loss:     0.4056 Validation Accuracy: 0.697800
# Epoch 79, CIFAR-10 Batch 3:  Loss:     0.4059 Validation Accuracy: 0.687600
# Epoch 79, CIFAR-10 Batch 4:  Loss:     0.3747 Validation Accuracy: 0.700200
# Epoch 79, CIFAR-10 Batch 5:  Loss:     0.3439 Validation Accuracy: 0.696000
# Epoch 80, CIFAR-10 Batch 1:  Loss:     0.3588 Validation Accuracy: 0.698200
# Epoch 80, CIFAR-10 Batch 2:  Loss:     0.4022 Validation Accuracy: 0.698000
# Epoch 80, CIFAR-10 Batch 3:  Loss:     0.3964 Validation Accuracy: 0.695000
# Epoch 80, CIFAR-10 Batch 4:  Loss:     0.3641 Validation Accuracy: 0.701000
# Epoch 80, CIFAR-10 Batch 5:  Loss:     0.3356 Validation Accuracy: 0.700400
# Epoch 81, CIFAR-10 Batch 1:  Loss:     0.3573 Validation Accuracy: 0.699800
# Epoch 81, CIFAR-10 Batch 2:  Loss:     0.3905 Validation Accuracy: 0.698000
# Epoch 81, CIFAR-10 Batch 3:  Loss:     0.3876 Validation Accuracy: 0.693400
# Epoch 81, CIFAR-10 Batch 4:  Loss:     0.3563 Validation Accuracy: 0.703000
# Epoch 81, CIFAR-10 Batch 5:  Loss:     0.3530 Validation Accuracy: 0.692000
# Epoch 82, CIFAR-10 Batch 1:  Loss:     0.3475 Validation Accuracy: 0.703000
# Epoch 82, CIFAR-10 Batch 2:  Loss:     0.3846 Validation Accuracy: 0.702400
# Epoch 82, CIFAR-10 Batch 3:  Loss:     0.4085 Validation Accuracy: 0.679000
# Epoch 82, CIFAR-10 Batch 4:  Loss:     0.3518 Validation Accuracy: 0.699800
# Epoch 82, CIFAR-10 Batch 5:  Loss:     0.3481 Validation Accuracy: 0.698600
# Epoch 83, CIFAR-10 Batch 1:  Loss:     0.3533 Validation Accuracy: 0.697800
# Epoch 83, CIFAR-10 Batch 2:  Loss:     0.3648 Validation Accuracy: 0.702200
# Epoch 83, CIFAR-10 Batch 3:  Loss:     0.3905 Validation Accuracy: 0.690400
# Epoch 83, CIFAR-10 Batch 4:  Loss:     0.3458 Validation Accuracy: 0.698400
# Epoch 83, CIFAR-10 Batch 5:  Loss:     0.3325 Validation Accuracy: 0.700800
# Epoch 84, CIFAR-10 Batch 1:  Loss:     0.3337 Validation Accuracy: 0.701400
# Epoch 84, CIFAR-10 Batch 2:  Loss:     0.3667 Validation Accuracy: 0.698600
# Epoch 84, CIFAR-10 Batch 3:  Loss:     0.3949 Validation Accuracy: 0.688200
# Epoch 84, CIFAR-10 Batch 4:  Loss:     0.3391 Validation Accuracy: 0.703400
# Epoch 84, CIFAR-10 Batch 5:  Loss:     0.3288 Validation Accuracy: 0.699800
# Epoch 85, CIFAR-10 Batch 1:  Loss:     0.3349 Validation Accuracy: 0.703800
# Epoch 85, CIFAR-10 Batch 2:  Loss:     0.3612 Validation Accuracy: 0.704400
# Epoch 85, CIFAR-10 Batch 3:  Loss:     0.3897 Validation Accuracy: 0.686200
# Epoch 85, CIFAR-10 Batch 4:  Loss:     0.3291 Validation Accuracy: 0.707600
# Epoch 85, CIFAR-10 Batch 5:  Loss:     0.3087 Validation Accuracy: 0.699800
# Epoch 86, CIFAR-10 Batch 1:  Loss:     0.3280 Validation Accuracy: 0.700600
# Epoch 86, CIFAR-10 Batch 2:  Loss:     0.3693 Validation Accuracy: 0.695800
# Epoch 86, CIFAR-10 Batch 3:  Loss:     0.3404 Validation Accuracy: 0.702400
# Epoch 86, CIFAR-10 Batch 4:  Loss:     0.3209 Validation Accuracy: 0.704800
# Epoch 86, CIFAR-10 Batch 5:  Loss:     0.3038 Validation Accuracy: 0.702400
# Epoch 87, CIFAR-10 Batch 1:  Loss:     0.3277 Validation Accuracy: 0.698800
# Epoch 87, CIFAR-10 Batch 2:  Loss:     0.3547 Validation Accuracy: 0.699800
# Epoch 87, CIFAR-10 Batch 3:  Loss:     0.3453 Validation Accuracy: 0.699000
# Epoch 87, CIFAR-10 Batch 4:  Loss:     0.3256 Validation Accuracy: 0.699400
# Epoch 87, CIFAR-10 Batch 5:  Loss:     0.3299 Validation Accuracy: 0.695600
# Epoch 88, CIFAR-10 Batch 1:  Loss:     0.3071 Validation Accuracy: 0.703000
# Epoch 88, CIFAR-10 Batch 2:  Loss:     0.3607 Validation Accuracy: 0.692800
# Epoch 88, CIFAR-10 Batch 3:  Loss:     0.3296 Validation Accuracy: 0.702800
# Epoch 88, CIFAR-10 Batch 4:  Loss:     0.3198 Validation Accuracy: 0.700400
# Epoch 88, CIFAR-10 Batch 5:  Loss:     0.3068 Validation Accuracy: 0.700600
# Epoch 89, CIFAR-10 Batch 1:  Loss:     0.3022 Validation Accuracy: 0.704400
# Epoch 89, CIFAR-10 Batch 2:  Loss:     0.3412 Validation Accuracy: 0.693400
# Epoch 89, CIFAR-10 Batch 3:  Loss:     0.3865 Validation Accuracy: 0.678800
# Epoch 89, CIFAR-10 Batch 4:  Loss:     0.3158 Validation Accuracy: 0.704200
# Epoch 89, CIFAR-10 Batch 5:  Loss:     0.2908 Validation Accuracy: 0.701200
# Epoch 90, CIFAR-10 Batch 1:  Loss:     0.3573 Validation Accuracy: 0.685600
# Epoch 90, CIFAR-10 Batch 2:  Loss:     0.3474 Validation Accuracy: 0.699800
# Epoch 90, CIFAR-10 Batch 3:  Loss:     0.3251 Validation Accuracy: 0.704400
# Epoch 90, CIFAR-10 Batch 4:  Loss:     0.3306 Validation Accuracy: 0.704400
# Epoch 90, CIFAR-10 Batch 5:  Loss:     0.2947 Validation Accuracy: 0.697400
# Epoch 91, CIFAR-10 Batch 1:  Loss:     0.3058 Validation Accuracy: 0.699400
# Epoch 91, CIFAR-10 Batch 2:  Loss:     0.3220 Validation Accuracy: 0.702000
# Epoch 91, CIFAR-10 Batch 3:  Loss:     0.3126 Validation Accuracy: 0.703600
# Epoch 91, CIFAR-10 Batch 4:  Loss:     0.3081 Validation Accuracy: 0.702600
# Epoch 91, CIFAR-10 Batch 5:  Loss:     0.2723 Validation Accuracy: 0.702400
# Epoch 92, CIFAR-10 Batch 1:  Loss:     0.2986 Validation Accuracy: 0.700800
# Epoch 92, CIFAR-10 Batch 2:  Loss:     0.3109 Validation Accuracy: 0.698800
# Epoch 92, CIFAR-10 Batch 3:  Loss:     0.3489 Validation Accuracy: 0.688600
# Epoch 92, CIFAR-10 Batch 4:  Loss:     0.2966 Validation Accuracy: 0.706000
# Epoch 92, CIFAR-10 Batch 5:  Loss:     0.2720 Validation Accuracy: 0.703000
# Epoch 93, CIFAR-10 Batch 1:  Loss:     0.3347 Validation Accuracy: 0.687000
# Epoch 93, CIFAR-10 Batch 2:  Loss:     0.3091 Validation Accuracy: 0.703600
# Epoch 93, CIFAR-10 Batch 3:  Loss:     0.3116 Validation Accuracy: 0.701000
# Epoch 93, CIFAR-10 Batch 4:  Loss:     0.3374 Validation Accuracy: 0.695400
# Epoch 93, CIFAR-10 Batch 5:  Loss:     0.2675 Validation Accuracy: 0.703800
# Epoch 94, CIFAR-10 Batch 1:  Loss:     0.3069 Validation Accuracy: 0.692000
# Epoch 94, CIFAR-10 Batch 2:  Loss:     0.3041 Validation Accuracy: 0.700800
# Epoch 94, CIFAR-10 Batch 3:  Loss:     0.2907 Validation Accuracy: 0.706200
# Epoch 94, CIFAR-10 Batch 4:  Loss:     0.3015 Validation Accuracy: 0.702800
# Epoch 94, CIFAR-10 Batch 5:  Loss:     0.2723 Validation Accuracy: 0.709800
# Epoch 95, CIFAR-10 Batch 1:  Loss:     0.2777 Validation Accuracy: 0.701200
# Epoch 95, CIFAR-10 Batch 2:  Loss:     0.3176 Validation Accuracy: 0.702800
# Epoch 95, CIFAR-10 Batch 3:  Loss:     0.3093 Validation Accuracy: 0.704000
# Epoch 95, CIFAR-10 Batch 4:  Loss:     0.3016 Validation Accuracy: 0.703400
# Epoch 95, CIFAR-10 Batch 5:  Loss:     0.2591 Validation Accuracy: 0.704600
# Epoch 96, CIFAR-10 Batch 1:  Loss:     0.2996 Validation Accuracy: 0.691400
# Epoch 96, CIFAR-10 Batch 2:  Loss:     0.3004 Validation Accuracy: 0.703800
# Epoch 96, CIFAR-10 Batch 3:  Loss:     0.2815 Validation Accuracy: 0.708600
# Epoch 96, CIFAR-10 Batch 4:  Loss:     0.3067 Validation Accuracy: 0.699000
# Epoch 96, CIFAR-10 Batch 5:  Loss:     0.2471 Validation Accuracy: 0.706600
# Epoch 97, CIFAR-10 Batch 1:  Loss:     0.2833 Validation Accuracy: 0.699400
# Epoch 97, CIFAR-10 Batch 2:  Loss:     0.2999 Validation Accuracy: 0.703200
# Epoch 97, CIFAR-10 Batch 3:  Loss:     0.2827 Validation Accuracy: 0.706800
# Epoch 97, CIFAR-10 Batch 4:  Loss:     0.2838 Validation Accuracy: 0.703000
# Epoch 97, CIFAR-10 Batch 5:  Loss:     0.2434 Validation Accuracy: 0.708600
# Epoch 98, CIFAR-10 Batch 1:  Loss:     0.2776 Validation Accuracy: 0.703200
# Epoch 98, CIFAR-10 Batch 2:  Loss:     0.2948 Validation Accuracy: 0.702600
# Epoch 98, CIFAR-10 Batch 3:  Loss:     0.2758 Validation Accuracy: 0.702600
# Epoch 98, CIFAR-10 Batch 4:  Loss:     0.2841 Validation Accuracy: 0.705600
# Epoch 98, CIFAR-10 Batch 5:  Loss:     0.2531 Validation Accuracy: 0.705200
# Epoch 99, CIFAR-10 Batch 1:  Loss:     0.2847 Validation Accuracy: 0.703200
# Epoch 99, CIFAR-10 Batch 2:  Loss:     0.2885 Validation Accuracy: 0.704400
# Epoch 99, CIFAR-10 Batch 3:  Loss:     0.2694 Validation Accuracy: 0.706000
# Epoch 99, CIFAR-10 Batch 4:  Loss:     0.2766 Validation Accuracy: 0.705400
# Epoch 99, CIFAR-10 Batch 5:  Loss:     0.2354 Validation Accuracy: 0.711800
# Epoch 100, CIFAR-10 Batch 1:  Loss:     0.2984 Validation Accuracy: 0.688800
# Epoch 100, CIFAR-10 Batch 2:  Loss:     0.2765 Validation Accuracy: 0.711400
# Epoch 100, CIFAR-10 Batch 3:  Loss:     0.2716 Validation Accuracy: 0.707000
# Epoch 100, CIFAR-10 Batch 4:  Loss:     0.2907 Validation Accuracy: 0.698600
# Epoch 100, CIFAR-10 Batch 5:  Loss:     0.2344 Validation Accuracy: 0.710000

# %% [markdown]
# # Checkpoint
# The model has been saved to disk.
# ## Test Model
# Test your model against the test dataset.  This will be your final accuracy. You should have an accuracy greater than 50%. If you don't, keep tweaking the model architecture and parameters.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()
    #init = tf.global_variables_initializer()
    config = tf.ConfigProto()
    #config.gpu_options.allow_growth = True
    config.gpu_options.per_process_gpu_memory_fraction = 0.5
    with tf.Session(config=config, graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# INFO:tensorflow:Restoring parameters from ./image_classification
# Testing Accuracy: 0.7115843949044586

# %% [markdown]
# ## Why 50-80% Accuracy?
# You might be wondering why you can't get an accuracy any higher. First things first, 50% isn't bad for a simple CNN.  Pure guessing would get you 10% accuracy. However, you might notice people are getting scores [well above 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130).  That's because we haven't taught you all there is to know about neural networks. We still need to cover a few more techniques.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook.  Save the notebook file as "dlnd_image_classification.ipynb" and save it as a HTML file under "File" -> "Download as".  Include the "helper.py" and "problem_unittests.py" files in your submission.
